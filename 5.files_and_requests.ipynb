# %%
# Прочитай файл Alenushka_i_Ivanushka.txt в папке support, выведи номера строк и сами строки, на которых есть слово: "Алёнушка".
# Формат: 11 Сестрица Алёнушка и братец Иванушка
# Out:
#  11 Сестрица Алёнушка и братец Иванушка
#  14 Жили-были старик да старуха, у них была дочка Алёнушка да сынок Иванушка.
#  16 Старик со старухой умерли. Остались Алёнушка да Иванушка одни-одинёшеньки.
#  18 Пошла Алёнушка на работу и братца с собой взяла. Идут они по дальнему пути, по широкому полю, и захотелось Иванушке пить.
#  20 – Сестрица Алёнушка, я пить хочу!
#  26 – Сестрица Алёнушка, хлебну я из копытца!
#  34 – Сестрица Алёнушка, напьюсь я из копытца!
#  44 – Сестрица Алёнушка, мочи нет: напьюсь я из копытца!
#  52 Зовёт Алёнушка братца, а вместо Иванушки бежит за ней беленький козлёночек.
#  54 Залилась Алёнушка слезами, села под стожок – плачет, а козлёночек возле неё скачет.
#  60 Рассказала ему Алёнушка про свою беду.
#  66 Алёнушка подумала, подумала и пошла за купца замуж.
#  78 		Алёнушка, сестрица моя!
#  97 		Алёнушка, сестрица моя!
# 104 Алёнушка из реки ему отвечает:
# 117 		Алёнушка, сестрица моя!
# ...

# %%
# Файл Baba_Yaga_cp1251.txt сохранен в кодировке отличной от стандартной utf-8, но мы знаем, что правильная кодировка файла 'cp1251' - кириллица windows.
# Прочти файл используя именованный аргумент encoding метода open с правильной кодировкой.
# Выведи на экран первые 830 символов файла.
# Out:
# Андрей Аливердиев
#
# Баба-Яга
#
#
# В этот вечер я чувствовал себя невероятно уставшим и, опустившись на диван, быстро погрузился в легкую дремоту, откуда меня вывело громкое мяуканье. Спросонья оно вызвало легкое недоумение: с тех пор как у сестры обнаружили аллергию, у нас дома не было представителей славного семейства кошачьих. Однако, открыв глаза, я сразу понял, откуда взялся этот гость. Конечно же, это был посыльный моего старого приятеля — Кота Ученого, что живет у Лукоморья. Моя комната была залита необычным светом, и все предметы выглядели неестественно яркими и красивыми, как на цветном плакате или в мультфильмах, с той лишь разницей, что объемность вещей была так же неестественно подчеркнутой. Впрочем, приход засланцев из Лукоморья всегда сопровождается такими эффектами, а мне это было, как говорится, не впервой.

# %%
# Файл Baba_Yaga_cp1251.txt сохранен в кодировке отличной от стандартной utf-8, но мы знаем, что правильная кодировка файла 'cp1251' - кириллица windows.
# Перекодируй файл в стандартную кодировку и сохрани перекодированный текст в файле Baba_Yaga_utf-8.txt в папке support.
# Хозяйке на заметку - стандартный метод записи write без параметров как раз сохраняет текст в нужном формате utf-8.

# %%
# Открой получившийся в предыдущем задании файл и объясни, что за аббревиатуры NBSP ты видишь в некоторых строчках

# %%
# запусти web server в терминале с помощью команды (если еще не запущен):  python utils/test_tasks_web_server.py
# Прочитай информацию из файла text_with_some_roman_numbers_utf-8.txt (кодировка utf-8) в папке support.
# Файл содержит последовательности символов, разделенных пробелом.
# Какие-то символы являются римскими числами, другие - нет.
# Нужно сосчитать сумму всех валидных (верных) римских чисел и умножить ее на количество валидных римских чисел.
# Для валидации и конвертации римских чисел нужно использовать API:
# API для валидации римских чисел: http://127.0.0.1:8005/is_roman_number/?roman_number={ROMAN_NUMBER}
# API для конвертации римского числа в арабское: http://127.0.0.1:8005/roman_to_integer/?roman_number={ROMAN_NUMBER}
# полученный ответ нужно отправить на API: http://127.0.0.1:8005/check_answer/?section=5?task=1?answer={ANSWER}
# И напечатать ответ.
